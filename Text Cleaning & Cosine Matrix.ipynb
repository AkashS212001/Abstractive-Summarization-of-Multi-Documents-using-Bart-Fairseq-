# %%
import pandas as pd
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# !pip install annoy
from annoy import AnnoyIndex
from datasketch import MinHash, MinHashLSHEnsemble
from sklearn.cluster import KMeans
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\senth\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Requirement already satisfied: annoy in c:\users\senth\anaconda3\lib\site-packages (1.17.3)

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#                                              src_content  dummy_column  \
# 0      National Archives NEWLINE_CHAR  NEWLINE_CHAR Y...           1.0
# 1      LOS ANGELES (AP) — In her first interview sinc...           1.0
# 2      GAITHERSBURG, Md. (AP) — A small, private jet ...           1.0
# 3      Tucker Carlson Exposes His Own Sexism on Twitt...           1.0
# 4      A man accused of removing another man's testic...           1.0
# ...                                                  ...           ...
# 44967  More than 670,000 copies of the Pearls’ self-p...           1.0
# 44968  Seeking out cost-conscious consumers who have ...           1.0
# 44969  Click to email this to a friend (Opens in new ...           1.0
# 44970  BARRINGTON, R.I. (AP) — Women clad in yoga pan...           1.0
# 44971  Based on a ‘real’ story, the hit John Travolta...           1.0
#
#                                              tgt_content  dummy_column.1
# 0      – The unemployment rate dropped to 8.2% last m...             1.0
# 1      – Shelly Sterling plans "eventually" to divorc...             1.0
# 2      – A twin-engine Embraer jet that the FAA descr...             1.0
# 3      – Tucker Carlson is in deep doodoo with conser...             1.0
# 4      – What are the three most horrifying words in ...             1.0
# ...                                                  ...             ...
# 44967  – The deaths of three children have been linke...             1.0
# 44968  – Apple is hoping its new, cheaper iPhone can ...             1.0
# 44969  – January Jones, who plays the beleaguered wif...             1.0
# 44970  – A Rhode Island man who penned a letter to th...             1.0
# 44971  – The Guardian revisits a fascinating piece of...             1.0
#
# [44972 rows x 4 columns]

# %%
df = df.drop(['dummy_column','dummy_column.1'], axis =1)

# %%
df
# Out:
#                                              src_content  \
# 0      National Archives NEWLINE_CHAR  NEWLINE_CHAR Y...
# 1      LOS ANGELES (AP) — In her first interview sinc...
# 2      GAITHERSBURG, Md. (AP) — A small, private jet ...
# 3      Tucker Carlson Exposes His Own Sexism on Twitt...
# 4      A man accused of removing another man's testic...
# ...                                                  ...
# 44967  More than 670,000 copies of the Pearls’ self-p...
# 44968  Seeking out cost-conscious consumers who have ...
# 44969  Click to email this to a friend (Opens in new ...
# 44970  BARRINGTON, R.I. (AP) — Women clad in yoga pan...
# 44971  Based on a ‘real’ story, the hit John Travolta...
#
#                                              tgt_content
# 0      – The unemployment rate dropped to 8.2% last m...
# 1      – Shelly Sterling plans "eventually" to divorc...
# 2      – A twin-engine Embraer jet that the FAA descr...
# 3      – Tucker Carlson is in deep doodoo with conser...
# 4      – What are the three most horrifying words in ...
# ...                                                  ...
# 44967  – The deaths of three children have been linke...
# 44968  – Apple is hoping its new, cheaper iPhone can ...
# 44969  – January Jones, who plays the beleaguered wif...
# 44970  – A Rhode Island man who penned a letter to th...
# 44971  – The Guardian revisits a fascinating piece of...
#
# [44972 rows x 2 columns]

# %%
#stop words removal

# %%
stop_words = stopwords.words('english')
df['src_content'] = df['src_content'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# %%
 #Stemming

# %%
# Initialize the stemmer
stemmer = PorterStemmer()

# Apply stemming to the 'text' column
df['src_content'] = df['src_content'].apply(lambda x: stemmer.stem(x))

# %%
df
# Out:
#                                              src_content  \
# 0      national archives newline_char newline_char ye...
# 1      los angeles (ap) — in first interview since nb...
# 2      gaithersburg, md. (ap) — a small, private jet ...
# 3      tucker carlson exposes his own sexism twitter ...
# 4      a man accused removing another man's testicle ...
# ...                                                  ...
# 44967  more 670,000 copies pearls’ self-published boo...
# 44968  seeking cost-conscious consumers gravitated to...
# 44969  click email friend (opens new window) newline_...
# 44970  barrington, r.i. (ap) — women clad yoga pants ...
# 44971  based ‘real’ story, hit john travolta film sat...
#
#                                              tgt_content
# 0      – The unemployment rate dropped to 8.2% last m...
# 1      – Shelly Sterling plans "eventually" to divorc...
# 2      – A twin-engine Embraer jet that the FAA descr...
# 3      – Tucker Carlson is in deep doodoo with conser...
# 4      – What are the three most horrifying words in ...
# ...                                                  ...
# 44967  – The deaths of three children have been linke...
# 44968  – Apple is hoping its new, cheaper iPhone can ...
# 44969  – January Jones, who plays the beleaguered wif...
# 44970  – A Rhode Island man who penned a letter to th...
# 44971  – The Guardian revisits a fascinating piece of...
#
# [44972 rows x 2 columns]

# %%
#Removal of unwanted email ids and websites

# %%
import re

def remove_emails_websites(text):
    # Remove email addresses
    text = re.sub(r'\S+@\S+', '', text)
    
    # Remove website links starting with http:// or https://
    text = re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text)
    
    return text

# %%
df['src_content'] = df['src_content'].apply(remove_emails_websites)

# %%
df
# Out:
#                                              src_content  \
# 0      national archives newline_char newline_char ye...
# 1      los angeles (ap) — in first interview since nb...
# 2      gaithersburg, md. (ap) — a small, private jet ...
# 3      tucker carlson exposes his own sexism twitter ...
# 4      a man accused removing another man's testicle ...
# ...                                                  ...
# 44967  more 670,000 copies pearls’ self-published boo...
# 44968  seeking cost-conscious consumers gravitated to...
# 44969  click email friend (opens new window) newline_...
# 44970  barrington, r.i. (ap) — women clad yoga pants ...
# 44971  based ‘real’ story, hit john travolta film sat...
#
#                                              tgt_content
# 0      – The unemployment rate dropped to 8.2% last m...
# 1      – Shelly Sterling plans "eventually" to divorc...
# 2      – A twin-engine Embraer jet that the FAA descr...
# 3      – Tucker Carlson is in deep doodoo with conser...
# 4      – What are the three most horrifying words in ...
# ...                                                  ...
# 44967  – The deaths of three children have been linke...
# 44968  – Apple is hoping its new, cheaper iPhone can ...
# 44969  – January Jones, who plays the beleaguered wif...
# 44970  – A Rhode Island man who penned a letter to th...
# 44971  – The Guardian revisits a fascinating piece of...
#
# [44972 rows x 2 columns]

# %%
#Removing Paranthesis and Hyphens

# %%
df['src_content'] = df['src_content'].str.replace(r'[\(\)\-]', '', regex=True)

# %%
df
# Out:
#                                              src_content  \
# 0      national archives newline_char newline_char ye...
# 1      los angeles ap — in first interview since nba ...
# 2      gaithersburg, md. ap — a small, private jet cr...
# 3      tucker carlson exposes his own sexism twitter ...
# 4      a man accused removing another man's testicle ...
# ...                                                  ...
# 44967  more 670,000 copies pearls’ selfpublished book...
# 44968  seeking costconscious consumers gravitated tow...
# 44969  click email friend opens new window newline_ch...
# 44970  barrington, r.i. ap — women clad yoga pants pl...
# 44971  based ‘real’ story, hit john travolta film sat...
#
#                                              tgt_content
# 0      – The unemployment rate dropped to 8.2% last m...
# 1      – Shelly Sterling plans "eventually" to divorc...
# 2      – A twin-engine Embraer jet that the FAA descr...
# 3      – Tucker Carlson is in deep doodoo with conser...
# 4      – What are the three most horrifying words in ...
# ...                                                  ...
# 44967  – The deaths of three children have been linke...
# 44968  – Apple is hoping its new, cheaper iPhone can ...
# 44969  – January Jones, who plays the beleaguered wif...
# 44970  – A Rhode Island man who penned a letter to th...
# 44971  – The Guardian revisits a fascinating piece of...
#
# [44972 rows x 2 columns]

# %%
#function to remove newline_char

# %%
def remove_word(df, src_content, word):
    df[src_content] = df[src_content].str.replace(word, '')
    return df
word_to_remove = 'newline_char'
column_name = 'src_content'
df = remove_word(df,column_name,word_to_remove)

# %%
df
# Out:
#                                              src_content  \
# 0      national archives   yes, it’s time again, folk...
# 1      los angeles ap — in first interview since nba ...
# 2      gaithersburg, md. ap — a small, private jet cr...
# 3      tucker carlson exposes his own sexism twitter ...
# 4      a man accused removing another man's testicle ...
# ...                                                  ...
# 44967  more 670,000 copies pearls’ selfpublished book...
# 44968  seeking costconscious consumers gravitated tow...
# 44969  click email friend opens new window   click sh...
# 44970  barrington, r.i. ap — women clad yoga pants pl...
# 44971  based ‘real’ story, hit john travolta film sat...
#
#                                              tgt_content
# 0      – The unemployment rate dropped to 8.2% last m...
# 1      – Shelly Sterling plans "eventually" to divorc...
# 2      – A twin-engine Embraer jet that the FAA descr...
# 3      – Tucker Carlson is in deep doodoo with conser...
# 4      – What are the three most horrifying words in ...
# ...                                                  ...
# 44967  – The deaths of three children have been linke...
# 44968  – Apple is hoping its new, cheaper iPhone can ...
# 44969  – January Jones, who plays the beleaguered wif...
# 44970  – A Rhode Island man who penned a letter to th...
# 44971  – The Guardian revisits a fascinating piece of...
#
# [44972 rows x 2 columns]

# %%
Truncated_data = df.head(1000)

# %%
Truncated_data
# Out:
#                                            src_content  \
# 0    national archives   yes, it’s time again, folk...
# 1    los angeles ap — in first interview since nba ...
# 2    gaithersburg, md. ap — a small, private jet cr...
# 3    tucker carlson exposes his own sexism twitter ...
# 4    a man accused removing another man's testicle ...
# ..                                                 ...
# 995  _______ |_ _| | | | | ____| | | | | | | | \___...
# 996  ramallah, west bank ap — a witness says member...
# 997  if you’ve ever thought birth control might mes...
# 998  friends say surprise reconciliation cards holl...
# 999  in 2005, witherspoon school law public policy ...
#
#                                            tgt_content
# 0    – The unemployment rate dropped to 8.2% last m...
# 1    – Shelly Sterling plans "eventually" to divorc...
# 2    – A twin-engine Embraer jet that the FAA descr...
# 3    – Tucker Carlson is in deep doodoo with conser...
# 4    – What are the three most horrifying words in ...
# ..                                                 ...
# 995  – Before dying by car bomb last October, Malte...
# 996  – A Palestinian Cabinet member has died amid a...
# 997  – Anyone who's struggled with mood swings whil...
# 998  – The faces of Demi and Ashton may be filling ...
# 999  – A pregnant Alabama woman who suffered a misc...
#
# [1000 rows x 2 columns]

# %%
#Removing the redunduncy present in the text by constructing cosine matrix

# %%
def remove_redundancy(Truncated_data, src_content):
    # Create TF-IDF vectorizer
    tfidf_vectorizer = TfidfVectorizer()

    # Fit and transform the text data
    tfidf_matrix = tfidf_vectorizer.fit_transform(Truncated_data[src_content])

    # Compute pairwise cosine similarity
    similarity_matrix = cosine_similarity(tfidf_matrix)
    print(similarity_matrix)

    # Create a mask to track redundant sentences
    mask = []

    for i in range(len(similarity_matrix)):
        # Check if the sentence is similar to any previous sentences
        if not any(similarity_matrix[i, j] > 0.9 for j in range(i)):
            mask.append(True)
        else:
            mask.append(False)

    # Filter out redundant sentences
    Truncated_data_filtered = Truncated_data[mask]

    return Truncated_data_filtered

# %%
column_name = 'src_content'

Truncated_data_filtered = remove_redundancy(Truncated_data, column_name)
print(Truncated_data_filtered)
# Out:
# [[1.         0.01706763 0.02710664 ... 0.02806697 0.02163965 0.02732097]
#  [0.01706763 1.         0.02104491 ... 0.00719449 0.02435722 0.02439763]
#  [0.02710664 0.02104491 1.         ... 0.01747572 0.02201428 0.0452059 ]
#  ...
#  [0.02806697 0.00719449 0.01747572 ... 1.         0.01252957 0.03260633]
#  [0.02163965 0.02435722 0.02201428 ... 0.01252957 1.         0.0325608 ]
#  [0.02732097 0.02439763 0.0452059  ... 0.03260633 0.0325608  1.        ]]
#                                            src_content  \
# 0    national archives   yes, it’s time again, folk...
# 1    los angeles ap — in first interview since nba ...
# 2    gaithersburg, md. ap — a small, private jet cr...
# 3    tucker carlson exposes his own sexism twitter ...
# 4    a man accused removing another man's testicle ...
# ..                                                 ...
# 995  _______ |_ _| | | | | ____| | | | | | | | \___...
# 996  ramallah, west bank ap — a witness says member...
# 997  if you’ve ever thought birth control might mes...
# 998  friends say surprise reconciliation cards holl...
# 999  in 2005, witherspoon school law public policy ...
#
#                                            tgt_content
# 0    – The unemployment rate dropped to 8.2% last m...
# 1    – Shelly Sterling plans "eventually" to divorc...
# 2    – A twin-engine Embraer jet that the FAA descr...
# 3    – Tucker Carlson is in deep doodoo with conser...
# 4    – What are the three most horrifying words in ...
# ..                                                 ...
# 995  – Before dying by car bomb last October, Malte...
# 996  – A Palestinian Cabinet member has died amid a...
# 997  – Anyone who's struggled with mood swings whil...
# 998  – The faces of Demi and Ashton may be filling ...
# 999  – A pregnant Alabama woman who suffered a misc...
#
# [999 rows x 2 columns]

# %%
Truncated_data_filtered
# Out:
#                                            src_content  \
# 0    national archives   yes, it’s time again, folk...
# 1    los angeles ap — in first interview since nba ...
# 2    gaithersburg, md. ap — a small, private jet cr...
# 3    tucker carlson exposes his own sexism twitter ...
# 4    a man accused removing another man's testicle ...
# ..                                                 ...
# 995  _______ |_ _| | | | | ____| | | | | | | | \___...
# 996  ramallah, west bank ap — a witness says member...
# 997  if you’ve ever thought birth control might mes...
# 998  friends say surprise reconciliation cards holl...
# 999  in 2005, witherspoon school law public policy ...
#
#                                            tgt_content
# 0    – The unemployment rate dropped to 8.2% last m...
# 1    – Shelly Sterling plans "eventually" to divorc...
# 2    – A twin-engine Embraer jet that the FAA descr...
# 3    – Tucker Carlson is in deep doodoo with conser...
# 4    – What are the three most horrifying words in ...
# ..                                                 ...
# 995  – Before dying by car bomb last October, Malte...
# 996  – A Palestinian Cabinet member has died amid a...
# 997  – Anyone who's struggled with mood swings whil...
# 998  – The faces of Demi and Ashton may be filling ...
# 999  – A pregnant Alabama woman who suffered a misc...
#
# [999 rows x 2 columns]

# %%
Truncated_data_filtered.loc[3,'src_content']
# Out:
# 'tucker carlson exposes his own sexism twitter updated   tucker carlson done good work past… his site, the daily caller, frequent stop mine many conservatives. they responsible exposing journolist scandal, highlighted planning coordination many members leftwing press. i always grateful tucker’s team bringing story light. this also i angered tucker’s recent actions. i thought better this.   if haven’t heard now, monday evening, tucker carlson posted disturbing tweet governor palin said:   palin’s popularity falling iowa, maintains lead become supreme commander milfistan   aside tucker’s sheeplike response warped poll numbers, also failed take ownership sexist comment. he deleted original which i link retweet obviously aware posted wrong. unfortunately him, many people already seen responded. you can’t put toothpaste back tube, tucker.   is sort treatment conservative women, want get involved process, expected put with? is okay male columnists conservative otherwise continue objectifying women world politics? no it’s not!   the best thing tucker carlson could do, admit tweeted wrong, apologize governor palin, urge fellow colleagues respectful language written word. what demeaning offensive, place conservative circles.   update: this poor attempt apology. tucker carlson tries cover tracks morning repeating mistakes made last night. he wrote:   apparently charlie sheen got control twitter account last night i dinner. apologies behavior.   he didn’t take responsibility comment fails horribly humor. try again, tucker… you’re funny.   update ii: almost day later, finally apologizes:   i’m sorry last night’s tweet. i meant absolutely offense. not first dumb thing i’ve said. hopefully last.     ||||| tweet location   you add location information tweets, city precise location, web via thirdparty applications. you always option delete tweet location history. learn ||||| i @karlrove @tuckercarlson misogynist mockery @sarahpalinusa . sick it. ||||| on monday night, rest world watching charlie sheen flame live cnn, tucker carlson took twitter make impolitic statements own.   "palin\'s popularity falling iowa, maintains lead become supreme commander milfistan," wrote.   by next morning, tweet deleted apologized, writing, “apparently charlie sheen got control twitter account last night i dinner. apologies behavior.”   but wasn’t enough spare ire conservative women blogosphere twitter.   on tuesday, carlson’s first apology, stacy drake, writing conservatives4palin, praised carlson’s works the daily caller, particularly leaks journolist emails, saying that’s tweet stung badly.   aside tucker’s sheeplike response warped poll numbers, also failed take ownership sexist comment. he deleted original which i link retweet obviously aware posted wrong. unfortunately him, many people already seen responded. you can’t put toothpaste back tube, tucker.     is sort treatment conservative women, want get involved process, expected put with? is okay male columnists conservative otherwise continue objectifying women world politics? no it’s not!     she unimpressed first apology, called apologize palin continuing denounce sexism twitter account.   michelle malkin joined calls tuesday, tweeting: “i @karlrove @tuckercarlson misogynist mockery @sarahpalinusa. sick it.”   later tuesday, carlson obliged: “i’m sorry last night’s tweet. i meant absolutely offense. not first dumb thing i’ve said. hopefully last.”   some bros come carlson\'s aid. tuesday, erick erickson tweeted, "maybe sense humor needs recalibrated, i heard @tuckercarlson\'s milfistan comment, i laughed got passport."   needless say, drake amused.   but wednesday, thing escalated fullblown war sexes within conservative blogosphere, whitney pitcher taking carlson\'s tweet inspiration post conservatives4palin: "milf–misogynists and elites i’d like fulminate."   perhaps additional reason governor palin win respect elite establishment cannot praised “perfectly creased pants” often wear skirt, right david  ...

# %%
Truncated_data_filtered
# Out:
#                                            src_content  \
# 0    national archives   yes, it’s time again, folk...
# 1    los angeles ap — in first interview since nba ...
# 2    gaithersburg, md. ap — a small, private jet cr...
# 3    tucker carlson exposes his own sexism twitter ...
# 4    a man accused removing another man's testicle ...
# ..                                                 ...
# 995  _______ |_ _| | | | | ____| | | | | | | | \___...
# 996  ramallah, west bank ap — a witness says member...
# 997  if you’ve ever thought birth control might mes...
# 998  friends say surprise reconciliation cards holl...
# 999  in 2005, witherspoon school law public policy ...
#
#                                            tgt_content
# 0    – The unemployment rate dropped to 8.2% last m...
# 1    – Shelly Sterling plans "eventually" to divorc...
# 2    – A twin-engine Embraer jet that the FAA descr...
# 3    – Tucker Carlson is in deep doodoo with conser...
# 4    – What are the three most horrifying words in ...
# ..                                                 ...
# 995  – Before dying by car bomb last October, Malte...
# 996  – A Palestinian Cabinet member has died amid a...
# 997  – Anyone who's struggled with mood swings whil...
# 998  – The faces of Demi and Ashton may be filling ...
# 999  – A pregnant Alabama woman who suffered a misc...
#
# [999 rows x 2 columns]

# %%
#Removing special character from dataframe
Truncated_data_filtered = Truncated_data_filtered.replace('[^\w\s]', '', regex=True)

# %%
Truncated_data_filtered
# Out:
#                                            src_content  \
# 0    national archives   yes its time again folks i...
# 1    los angeles ap  in first interview since nba b...
# 2    gaithersburg md ap  a small private jet crashe...
# 3    tucker carlson exposes his own sexism twitter ...
# 4    a man accused removing another mans testicle m...
# ..                                                 ...
# 995  _______ _ _     ____        ______ ournalist n...
# 996  ramallah west bank ap  a witness says member p...
# 997  if youve ever thought birth control might mess...
# 998  friends say surprise reconciliation cards holl...
# 999  in 2005 witherspoon school law public policy h...
#
#                                            tgt_content
# 0     The unemployment rate dropped to 82 last mont...
# 1     Shelly Sterling plans eventually to divorce h...
# 2     A twinengine Embraer jet that the FAA describ...
# 3     Tucker Carlson is in deep doodoo with conserv...
# 4     What are the three most horrifying words in t...
# ..                                                 ...
# 995   Before dying by car bomb last October Maltese...
# 996   A Palestinian Cabinet member has died amid a ...
# 997   Anyone whos struggled with mood swings while ...
# 998   The faces of Demi and Ashton may be filling s...
# 999   A pregnant Alabama woman who suffered a misca...
#
# [999 rows x 2 columns]

# %%
#Cleaning the Tgt content which is the summary for the multi document summarizaion

# %%
#Removing Paranthesis and Hyphens
Truncated_data_filtered['tgt_content'] = Truncated_data_filtered['tgt_content'].str.replace(r'[\(\)\-]', '', regex=True)

# %%
#function to remove newline_char

# %%
def remove_word(Truncated_data_filtered, tgt_content, word):
    df[tgt_content] = df[tgt_content].str.replace(word, '')
    return Truncated_data_filtered
word_to_remove = 'newline_char'
column_name = 'tgt_content'
Truncated_data_filtered = remove_word(Truncated_data_filtered,column_name,word_to_remove)

# %%
Truncated_data_filtered
# Out:
#                                            src_content  \
# 0    national archives   yes its time again folks i...
# 1    los angeles ap  in first interview since nba b...
# 2    gaithersburg md ap  a small private jet crashe...
# 3    tucker carlson exposes his own sexism twitter ...
# 4    a man accused removing another mans testicle m...
# ..                                                 ...
# 995  _______ _ _     ____        ______ ournalist n...
# 996  ramallah west bank ap  a witness says member p...
# 997  if youve ever thought birth control might mess...
# 998  friends say surprise reconciliation cards holl...
# 999  in 2005 witherspoon school law public policy h...
#
#                                            tgt_content
# 0     The unemployment rate dropped to 82 last mont...
# 1     Shelly Sterling plans eventually to divorce h...
# 2     A twinengine Embraer jet that the FAA describ...
# 3     Tucker Carlson is in deep doodoo with conserv...
# 4     What are the three most horrifying words in t...
# ..                                                 ...
# 995   Before dying by car bomb last October Maltese...
# 996   A Palestinian Cabinet member has died amid a ...
# 997   Anyone whos struggled with mood swings while ...
# 998   The faces of Demi and Ashton may be filling s...
# 999   A pregnant Alabama woman who suffered a misca...
#
# [999 rows x 2 columns]

# %%
Truncated_data_filtered.to_csv('Train_Truncated_Data.csv', index=False)
